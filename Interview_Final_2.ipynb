# %%
import openai
from dotenv import load_dotenv
import os
import random
import re

# ===== 환경 설정 =====
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
client = openai.Client()

TOTAL_QUESTIONS = 3

SKIP_KEYWORDS = [
    "다음 질문", "다음질문", "스킵", "skip", "pass", "next",
    "next question", "넘어가기", "넘어가자", "넘어갈게요"
]

# 태도/모범/성실 칭찬만 제거
EXCLUDE_KEYWORDS = [
    "성실", "성실함", "성실하게", "모범", "모범적인",
    "태도", "태도가", "자세가 좋", "정성을 다해",
    "발표한 모습이 보기 좋았", "발표를 잘함", "발표를 잘 하",
    "참여도가 높", "열심히 참여", "적극적으로 참여",
    "친구들과 잘 지내", "봉사정신이 투철", "예의바른 태도"
]

# 희망 분야 매핑
CAREER_SUBJECT_MAP = {
    "공학": ["수학", "기하", "미적", "미적분", "과학", "물리",
           "융합과학", "정보", "프로그래밍", "공학", "인공지능 수학"],
    "자연": ["생명", "생명과학", "화학", "지구", "지구과학", "물리", "과학"],
    "의학": ["생명", "생명과학", "화학", "보건", "의학"],
    "컴퓨터": ["정보", "프로그래밍", "AI", "데이터", "수학",
            "기하", "미적분", "인공지능 수학", "컴퓨터공학"],
    "소프트웨어": ["정보", "프로그래밍", "AI", "컴퓨터", "수학"],
    "AI": ["정보", "프로그래밍", "AI", "융합과학", "수학", "인공지능 수학"],
    "상경": ["경제", "사회", "정치", "수학", "확률과통계"],
    "경영": ["경영", "경제", "사회", "수학"],
    "인문": ["국어", "문학", "독서", "사회", "윤리", "철학"],
    "교육": ["교육", "심리", "국어", "사회"]
}

##########################################################
# 1. 전체 텍스트 합치기
##########################################################
def get_full_text(student_data):
    records = student_data.get("academic_records", [])
    if isinstance(records, list):
        full = "\n".join(str(x) for x in records)
    else:
        full = str(records)

    reading = student_data.get("reading", "")
    if reading:
        full += "\n" + str(reading)

    return full


##########################################################
# 2. 희망분야 → 학년별 자동 배정
##########################################################
def extract_career_by_grade(full_text):
    matches = re.findall(r"희망\s*분야\s*([^\n]+)", full_text)

    grade_raw = {1: None, 2: None, 3: None}
    for idx, raw in enumerate(matches[:3], start=1):
        cleaned = raw.replace("분야", "").replace("계열", "").strip()
        grade_raw[idx] = cleaned

    def normalize(field):
        if not field:
            return ""
        if "컴퓨터" in field or "소프트웨어" in field:
            return "컴퓨터"
        if "ai" in field.lower():
            return "AI"
        if "공학" in field:
            return "공학"
        if "자연" in field:
            return "자연"
        if "의학" in field:
            return "의학"
        if "경영" in field:
            return "경영"
        if "상경" in field:
            return "상경"
        if "인문" in field:
            return "인문"
        if "교육" in field:
            return "교육"
        return field

    grade_norm = {g: normalize(v) for g, v in grade_raw.items()}
    return grade_raw, grade_norm


##########################################################
# 3. 세특/창체 출처 자동 추출
##########################################################
def extract_sources(full_text):
    sources = []

    # 3-1) 세부능력특기사항
    pattern = re.compile(
        r"([가-힣A-Za-z0-9\s]+):\s*(.+?)(?=\n[가-힣A-Za-z0-9\s]+:|\n동아리활동|\n자율활동|\n진로활동|\n봉사활동|\Z)",
        re.DOTALL
    )

    for m in pattern.finditer(full_text):
        subject = m.group(1).strip()
        desc = m.group(2).strip().replace("\n", " ")[:250]
        label = f"{subject}(세부능력특기사항)"
        sources.append((label, desc))

    # 3-2) 창체
    blocks = ["동아리활동", "자율활동", "진로활동", "봉사활동"]
    for b in blocks:
        bpat = re.compile(
            b + r"\s*\n(.+?)(?=\n동아리활동|\n자율활동|\n진로활동|\n봉사활동|\Z)",
            re.DOTALL
        )
        for m in bpat.finditer(full_text):
            desc = m.group(1).strip().replace("\n", " ")[:250]
            sources.append((b, desc))

    return sources


##########################################################
# 4. 태도성 내용 제거
##########################################################
def filter_out_attitude(sources):
    clean = []
    for label, text in sources:
        combo = label + " " + text
        if not any(bad in combo for bad in EXCLUDE_KEYWORDS):
            clean.append((label, text))
    return clean


##########################################################
# 5. label → 과목명/활동종류 분리
##########################################################
def split_label(label):
    """
    label 예:
    - '인공지능 수학(세부능력특기사항)'
    - '동아리활동'
    """
    if "(" in label:
        subject = label.split("(")[0]
        activity = label[label.find("(")+1:-1]
    else:
        subject = label
        activity = "창체활동"

    return subject.strip(), activity.strip()


##########################################################
# 6. 메인 로직
##########################################################
def start_ai_interview(student_data):
    full_text = get_full_text(student_data)

    # --- 희망분야 추출 ---
    career_raw, career_norm = extract_career_by_grade(full_text)

    print("\n=== 희망분야 인식 결과 ===")
    for g in [1,2,3]:
        print(f"{g}학년 → {career_raw.get(g)} (키워드: {career_norm.get(g)})")
    print("==========================\n")

    # --- 출처 추출 ---
    sources = extract_sources(full_text)
    sources = filter_out_attitude(sources)

    if not sources:
        print("출처 없음. JSON 구조 확인 필요.")
        return

    # --- A 모드 SYSTEM PROMPT ---
    system_prompt = '''
너는 대한민국 최상위권 공대 면접관이다.
매우 냉정하고 날카롭게 평가하며 생기부와 무관한 답변은 모두 혹평하라.
점수 < 70점이면 반드시 [다시 답변 요청]을 붙인다.
'''

    messages = [{"role": "system", "content": system_prompt}]

    question_num = 1

    while question_num <= TOTAL_QUESTIONS:

        # === 1) 학년 랜덤 선택 ===
        selected_grade = random.choice([1,2,3])
        selected_career_raw = career_raw[selected_grade]
        selected_career_norm = career_norm[selected_grade]

        # === 2) 해당 학년 희망분야 기반 필터 ===
        allowed_keywords = CAREER_SUBJECT_MAP.get(selected_career_norm, [])
        grade_sources = [
            s for s in sources if any(k in (s[0] + s[1]) for k in allowed_keywords)
        ]
        if not grade_sources:
            grade_sources = sources

        # === 3) 출처 선택 ===
        label, text = random.choice(grade_sources)
        subject_name, activity_type = split_label(label)

        is_last = (question_num == TOTAL_QUESTIONS)

        # === 4) 질문 생성 ===
        user_prompt = f'''
다음 정보를 기반으로 {"[마지막 질문]" if is_last else "[질문]"}을 생성하라.

출처 학년: {selected_grade}학년
과목명: {subject_name}
활동종류: {activity_type}
출처 전문: {label}
핵심 내용: {text}

해당 학년 희망분야: {selected_career_raw} (키워드: {selected_career_norm})

형식:
{"[마지막 질문]" if is_last else "[질문]"}
출처: {selected_grade}학년 · {subject_name} ({activity_type})
희망분야({selected_grade}학년): {selected_career_raw}
핵심 내용: {text}
질문:
'''
        messages.append({"role": "user", "content": user_prompt})

        resp = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            max_tokens=600
        )
        qtext = resp.choices[0].message.content
        print("\n" + qtext)
        messages.append({"role": "assistant", "content": qtext})

        # === 5) 답변 받기 ===
        answer = input("\n[학생 답변 또는 '다음 질문'] > ")

        if any(k in answer.lower() for k in SKIP_KEYWORDS):
            print("\n[안내] 다음 질문으로 넘어갑니다.\n")
            question_num += 1
            continue

        if answer.lower() in ("exit", "quit"):
            print("면접을 종료합니다.")
            break

        # === 6) 평가 ===
        eval_prompt = f'''
[학생 답변]
{answer}

출처 학년: {selected_grade}학년
과목명: {subject_name}
활동종류: {activity_type}
출처 전문: {label}
핵심 내용: {text}
희망분야({selected_grade}학년): {selected_career_raw}

A 모드로 매우 날카롭게 평가하라.
'''
        messages.append({"role": "user", "content": eval_prompt})

        resp = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=messages,
            max_tokens=900
        )
        eval_text = resp.choices[0].message.content
        print("\n" + eval_text)
        messages.append({"role": "assistant", "content": eval_text})

        if "[다시 답변 요청]" in eval_text:
            continue

        question_num += 1

RECORDINGS_DIR = "recordings_lite"

def load_student_txt(filepath):
    """
    생활기록부 TXT 파일을 기존 코드가 쓰는 student_data 구조로 변환
    """
    with open(filepath, "r", encoding="utf-8") as f:
        text = f.read().strip()

    # 이름 추출 (없으면 기본값)
    name_match = re.search(r"이름\s*[:：]\s*(.+)", text)
    name = name_match.group(1).strip() if name_match else "이름 미상"

    return {
        "student_info": {
            "name": name
        },
        # 기존 로직은 academic_records를 텍스트로 처리 가능
        "academic_records": text,
        "reading": ""
    }


##########################################################
# 실행
##########################################################
if __name__ == "__main__":

    files = [
        f for f in os.listdir(RECORDINGS_DIR)
        if f.endswith(".txt")
    ]

    if not files:
        print("❌ recordings 폴더에 TXT 파일이 없습니다.")
        exit()

    for filename in files:
        filepath = os.path.join(RECORDINGS_DIR, filename)

        print("\n" + "=" * 70)
        print(f"🎯 면접 시작: {filename}")
        print("=" * 70)

        try:
            student_data = load_student_txt(filepath)
        except Exception as e:
            print(f"❌ 파일 로딩 실패: {filename} ({e})")
            continue

        name = student_data["student_info"]["name"]
        print(f"👤 학생 이름: {name}\n")

        start_ai_interview(student_data)

        print("\n✅ 해당 학생 면접 종료\n")

        cmd = input("👉 다음 학생으로 진행하려면 Enter (종료: exit) > ")
        if cmd.lower() in ("exit", "quit"):
            print("전체 면접을 종료합니다.")
            break
# Out:
# ======================================================================
# 🎯 면접 시작: 202311093_1학년_컴퓨터과학과_유선웅_정시_censored.txt
# ======================================================================
# 👤 학생 이름: 이름 미상
#
#
# === 희망분야 인식 결과 ===
# 1학년 → 소프트웨어전문가 자신이 가진 재능과 능력올 학교에서 발휘해 친구와 선생님들올 도우면서 . 자신의 꿈 올 실현하기 위해 많은 노력올 기울이는 학생임 . 학급 , 학교 학생회 ,  동아리 등에서도 자신의 진로와 연결시켜 노력하는 모습음 많이 보임 청소년 직업흥미검사 (2019.04.05)에서 일반흥미는 관습형과 현실형이없으머   기초흥 미는 기계 , 기술 및 음악분아로 나타남. 과학창의 교실 1차 (2019.05.15. /8시간) 에 참여하이 '알아두면 쓸모 있는 신기한 멸치 진로활동 37 해부 화학 발광의 조도에 미치는 혹매의 여할" 주제로 창의적인 교과 인구활동에 참여 함. 금요일에 과학터지 (2019.03. 29/2시간)에 참가하이 '컴퓨터 발전과 양자컴퓨터 시대' 에 대한 강연올 듣고, 양자 컴퓨터 개발로 새로운 시대가 열질 것으로 예측함. 수학문화 축전 (2019.04,05/2시간) 에 참가하여 '유금리드 원론 등 기학학음 다른 모양 의 수학' 올 주제로 체험올 함. 수학과 과학 박물관에 자주 가켓다고 생각올 하기 팀, 학생부종합전형 평가 기준과 평가 방법의 이해 (2019.06. 21/2시간) 에 대한 강의름 들 개인정보 및 저작권 보호 교육(2020.05. 01,/1시간) 에 참여하여 관련 자료률 탄색 및 학습함으로씨 디지털 시민 의식올 함양함. 직접 귀즈률 제작하고 해결하는 과정올 통 해 온라인 수업에서의 네티켓올 익험. 내가 설계하는 진학 로드맵 (2020.07.10./3시간) 올 동해 '2022 대입의 변화 이해 . 대입 전형 유형별 특징 이해' 영상울 시청하고   진학 사이트에서 내 성적으로 갈 수 잎 자율활동 65 논 대학 정보 및 대학별 합불 자료률 검색하고 진학 로드맵올 설계함. 관심사 학급 친구와 공유하기 (2020.07.31. /1시간) 활동올 통해 자신의 관심사인 컴퓨 터의 구조와 프로그램 등에 대해 설명하고   친구들의 관심사에 대해 흥미름 가지고 경 청하는 태도릎 보임, 인터넷 스마트포 중독 예방 교육(2020.1127,/1시간) 올 통해 스마트프은 생활올 편리 하고 즐겁계 해주는 도구이지만 과의존하는 경우 여러 문제가 발생할 수 있으므로 스 마트포올 목적과 계획에 맞게 사용하고 자기 조절력올 키우는 짓이 중요함을 알게 팀. (키워드: 컴퓨터)
# 2학년 → IT'  효율적인 시간관리름 통한 자아존중감 향상 (2020.09.16. / 1시간) 활동올 통해 효과적 인 시간 관리 방법에 대해 배움 교내 화학캠 프 (2020.10.24./3시간) 에서 제대로 표시되지 암은 물질의 형태 , 모양 깔이 비슷한 약물과 식용 재료가 흔동되어 있을 때 이름 체계적인 화학반응 분석올 통 해 구분하는 방법올 담구함 . 식용 재료에 오염되어 있는 각각의 약물의 양울 상대적으 진로활동 33 로 비교 분석하이 약물중독의 원인올 찾아봄 , 약품의 오남용에 따른 약물중독 위험올 주제로 토의함 . 회복단력성 키우기 (2020.10.28. /1시간) 활동으로 여경을 극복해번 사람들의 사례름 통해 여경올 극복하는 마음가짐과 방법에 대해 배움 청춘의 미래틀 어는 세 번의 여행 진로 특강 (2020.12.11, /2시간) 올 통해 얼마나 '멀리 가느나가 아니라 얼마나 '낯설계' 바라보느나가 중요하다는 여행의 진정한 의미에 대 해 배우고   여행올 준비하는 방법과 여행 시 가져야 할 마음가짐에 대해 학습함. 1학기 동안 학급의 학습부원으로 활동하면서 반의 면학 분위기률 조성하고 다양하 학 숨 자료률 제공해주벼 시험기간에는 시험범위 공지나 수행평가 일정 알려주는 등 반율 위해 봉사함. 포스트코로나 시대에 적응하기 관련 토론에서 코로나 이후에 사람들이 건강에 더욱 맘 은 관심올 가지게 되울 깨닫게 뇌엇고 거리두기가 일상화되면서 변화하게 되는 많은 부 자율활동 70 분들에 대해 반 친구들과 의견올 나늄. 이러한 변화가 잠깐으로 끝나는 것이 아니라 앞 으로의 시대는 이러한 비대면 활동이 증가할 예정이므로 자신이 관심 앞는 에서의 변화름 빠르게 알아차리고 대비하는 것이 중요함올 생각해보는 시간율 가짐. 실생활로 들어온 인공지능에 대한 토론에서 인공지능이 어떠한 특정 영역에서만 사용 되는 짓이 아니라 우리 주변에서도 이제 심게 불 수 있음올 이해하고 이러한 인공지능 시대에 자신만의 강점올 기르기 위해서는 어떠한 노력이 필요한지 함께 고민해 보는 시 간을 가짐 등올 (키워드: IT'  효율적인 시간관리름 통한 자아존중감 향상 (2020.09.16. / 1시간) 활동올 통해 효과적 인 시간 관리 방법에 대해 배움 교내 화학캠 프 (2020.10.24./3시간) 에서 제대로 표시되지 암은 물질의 형태 , 모양 깔이 비슷한 약물과 식용 재료가 흔동되어 있을 때 이름 체계적인 화학반응 분석올 통 해 구분하는 방법올 담구함 . 식용 재료에 오염되어 있는 각각의 약물의 양울 상대적으 진로활동 33 로 비교 분석하이 약물중독의 원인올 찾아봄 , 약품의 오남용에 따른 약물중독 위험올 주제로 토의함 . 회복단력성 키우기 (2020.10.28. /1시간) 활동으로 여경을 극복해번 사람들의 사례름 통해 여경올 극복하는 마음가짐과 방법에 대해 배움 청춘의 미래틀 어는 세 번의 여행 진로 특강 (2020.12.11, /2시간) 올 통해 얼마나 '멀리 가느나가 아니라 얼마나 '낯설계' 바라보느나가 중요하다는 여행의 진정한 의미에 대 해 배우고   여행올 준비하는 방법과 여행 시 가져야 할 마음가짐에 대해 학습함. 1학기 동안 학급의 학습부원으로 활동하면서 반의 면학 분위기률 조성하고 다양하 학 숨 자료률 제공해주벼 시험기간에는 시험범위 공지나 수행평가 일정 알려주는 등 반율 위해 봉사함. 포스트코로나 시대에 적응하기 관련 토론에서 코로나 이후에 사람들이 건강에 더욱 맘 은 관심올 가지게 되울 깨닫게 뇌엇고 거리두기가 일상화되면서 변화하게 되는 많은 부 자율활동 70 분들에 대해 반 친구들과 의견올 나늄. 이러한 변화가 잠깐으로 끝나는 것이 아니라 앞 으로의 시대는 이러한 비대면 활동이 증가할 예정이므로 자신이 관심 앞는 에서의 변화름 빠르게 알아차리고 대비하는 것이 중요함올 생각해보는 시간율 가짐. 실생활로 들어온 인공지능에 대한 토론에서 인공지능이 어떠한 특정 영역에서만 사용 되는 짓이 아니라 우리 주변에서도 이제 심게 불 수 있음올 이해하고 이러한 인공지능 시대에 자신만의 강점올 기르기 위해서는 어떠한 노력이 필요한지 함께 고민해 보는 시 간을 가짐 등올)
# 3학년 → 컴퓨터공학 다양한 분아에 호기심이 맘고 특히 컴퓨터 공학 계엽에 관심울 드리냄. 자신의 진로에 대한 진지한 고민과 함께 학업올 열심히 하는 것율 최우선 목표로 선정함 . 미래의 모습 울 상상하다 미래의 자신에게 편지쓰기 활동울 하여 ,  어떻게 인생울 설계하는 것이 종 진로환동 29 울지 진로 곡선 그래프물 그리며 구체적인 인생 계획울 설계해 봄 . 자신이 관심울 가지 고 있는 분아에서 대표적인 도서물 살펴보고 도서출 스스로 선정하여 매주 조금씩 위고 관심사가 비슷한 친구들과 토론하면서 느낌 점울 발표하는 시간올 가짐 . 최근데 눈부 신 발전올 하고 있는 컴퓨터 관련 기사와 농영상울 조사하여 최신 뉴스와 관련 이수들 올 인식하고 친구들과 함께 공유함 봉 사 활 동 실 적 일자 또는 기간 장소 또는 주관기관명 활동내용 시간 누계시간 2019.03.15. (학교) 청원고등학교 봉사환동 안내 자원봉사활동의 의의와 필요성 2019.04,05, (학교) 청원 고등학교 안내 2019.05. 31 (학교) 칭원고등학교 자연보호 및 환경정화 활동 미세먼지 그것이 알고 싶다 캠페 2019.06.01 (개인) 중랑천환경센터 인 활동 2019.08.16. (학교) 청원고등학교 자원봉사활동의 유의점 안내 2019.09.20. (학교) 청원고등학교 봉사활동기초교육 2019.09.27. (학교) 청원고등학교 자연보호 및 환경정화 활동 제2회 노원 도봉 청소년 문화한 2019.10, 27 (개인) 노원 도봉 교육공동체 마당 한글사랑 , 사랑 가두 캠페인 2019.11.01 (학교) 청원고등학교 봉사활동 장애 교육 2019.1101. (학교) 청원고등학교 봉사활동 환경교육 13 2019.12.06. (학교) 청원고등학교 봉사활동 사례안내 2019.12,20 (학교) 청원 고등학교 봉사활동 평가 및 소감 발표회 15 학 년 (키워드: 컴퓨터)
# ==========================
#
#
# [질문]
# 한국사 수업에서 역사적 사건에 대한 질문이 많았다고 하셨습니다. 그 중에서 어떠한 사건이 가장 기억에 남았으며, 그 사건이 현대 사회에 미친 영향에 대해 본인의 주관적인 의견을 제시해 주시겠습니까? 설명에 있어 분석적 접근을 부탁드립니다.
#
# 출처: 3학년 · 이수단위 합계 52 과목 세부 능력 및 특기 사항 한국사 (세부능력특기사항)
# 희망분야(3학년): 컴퓨터공학
# 핵심 내용: 수업시간에 질문이 많았던 학생, 역사적 사건에 대한 분석 및 이해를 통해 교사의 질문에 예리하게 답변한 적 있음.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 341
#     338 name = student_data["student_info"]["name"]
#     339 print(f"👤 학생 이름: {name}\n")
# --> 341 start_ai_interview(student_data)
#     343 print("\n✅ 해당 학생 면접 종료\n")
#     345 cmd = input("👉 다음 학생으로 진행하려면 Enter (종료: exit) > ")
#
# Cell In[2], line 247, in start_ai_interview(student_data)
#     244 messages.append({"role": "assistant", "content": qtext})
#     246 # === 5) 답변 받기 ===
# --> 247 answer = input("\n[학생 답변 또는 '다음 질문'] > ")
#     249 if any(k in answer.lower() for k in SKIP_KEYWORDS):
#     250     print("\n[안내] 다음 질문으로 넘어갑니다.\n")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
